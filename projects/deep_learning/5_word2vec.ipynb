# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'originated', 'term', 'term', 'of', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

# Words used for the testing:
word_1="paris"
word_2="france"
word_3="italy"
exp_word="rome"

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  
  print(valid_embeddings.get_shape())
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
  
  def word_relation_test():
    emb1=tf.nn.embedding_lookup(normalized_embeddings,count[dictionary[word_1]][1])
    emb2=tf.nn.embedding_lookup(normalized_embeddings,count[dictionary[word_2]][1])
    emb3=tf.nn.embedding_lookup(normalized_embeddings,count[dictionary[word_3]][1])
    
    emb4 = emb1-emb2+emb3
    
    emb4 = tf.expand_dims(emb4,1) # to make the embedding a matrix as it's required by MatMul
    print(emb4.get_shape())
    return tf.transpose(emb4)
    
  test_relations = tf.matmul(word_relation_test(),tf.transpose(normalized_embeddings))
# Out:
# (16, 128)
# (128, 1)

# %%
num_steps = 100001
#num_steps = 11

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
     
  #testing the word relationships
  test_k=5
  test=test_relations.eval()
  nearest = (-test[0][:]).argsort()[1:test_k+1]
  
  possible_answers=[]
  for k in range(test_k):
        possible_answers.append(reverse_dictionary[nearest[k]])
        
  log = 'Paris - France + Rome = %s,' % (possible_answers)
  print(log)
    
     
    
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.379778
# Nearest to system: grammy, pierre, ebcdic, peninsula, derogatory, hasidism, interrupts, kapellmeister,
# Nearest to five: promulgated, glance, fastest, facilitator, cordon, usability, believers, abbasids,
# Nearest to there: marmara, hesychasm, bessarabia, mahmud, vega, eschewing, interruptions, pontiff,
# Nearest to world: christiania, keller, chunk, janissaries, burmese, end, eject, reagan,
# Nearest to war: restyled, stadler, ligature, incubus, unusually, additional, instincts, mitre,
# Nearest to these: catchphrase, wakizashi, articles, unimaginable, itis, antiprism, valuable, handover,
# Nearest to on: lunches, personifications, sta, acad, alioth, leningrad, khalil, sarti,
# Nearest to however: crowned, observed, printable, sahib, cubs, twas, strau, ergaster,
# Nearest to about: sosa, escorial, manga, wildstorm, organically, tag, brahmin, ean,
# Nearest to often: penance, anchor, mcluhan, unionist, differing, deepening, nearer, mistletoe,
# Nearest to d: architecture, exons, email, indignant, broca, skunk, laments, vert,
# Nearest to called: clandestine, adlai, bootleg, aphrodite, scribner, simone, orbiter, thirsty,
# Nearest to during: asic, refutable, foreword, purge, wields, permeated, underdeveloped, certifying,
# Nearest to their: ruby, tang, sms, kevlar, amplifiers, serie, cognomen, buttstock,
# Nearest to so: mellor, elie, browsing, interacting, barns, postpartum, rah, kovacs,
# Nearest to see: valence, replied, shanahan, plenary, remainder, oscillations, eighth, agreement,
# Average loss at step 2000: 4.415808
# Average loss at step 4000: 3.892674
# Average loss at step 6000: 3.556254
# Average loss at step 8000: 3.634999
# Average loss at step 10000: 3.693555
# Nearest to system: alpaca, derogatory, hasidism, reports, grammy, disqualified, conditions, interrupts,
# Nearest to five: six, four, eight, nine, seven, zero, three, two,
# Nearest to there: it, marmara, pontiff, neapolitan, died, which, salvatore, berkman,
# Nearest to world: strain, pickup, unacceptable, boxcar, following, reagan, uterus, janissaries,
# Nearest to war: stadler, restyled, ligature, ccc, additional, earlier, unusually, charlemagne,
# Nearest to these: some, many, articles, tarquinius, alertness, arroyo, the, cummings,
# Nearest to on: from, in, sta, liquid, merseyside, cartoonish, lunches, rescued,
# Nearest to however: ddo, sahib, nuggets, printable, scrapped, strau, beckham, observed,
# Nearest to about: brahmin, tag, escorial, raider, amato, sosa, bow, grt,
# Nearest to often: sometimes, also, darkened, kwh, easier, opening, penance, personhood,
# Nearest to d: architecture, skunk, broca, email, exons, indignant, perturbations, shamanism,
# Nearest to called: substantive, backers, milanese, duets, covert, mauretania, improv, mailed,
# Nearest to during: in, at, refutable, underdeveloped, superheroes, mounts, macs, certifying,
# Nearest to their: the, its, his, serie, ericaceae, jurassic, opting, kevlar,
# Nearest to so: drifted, much, kovacs, seismic, went, barns, duals, rah,
# Nearest to see: valence, tokyo, israelite, inhibitor, conversational, pyrrhus, mountain, communes,
# Average loss at step 12000: 3.625747
# Average loss at step 14000: 3.593323
# Average loss at step 16000: 3.572810
# Average loss at step 18000: 3.541472
# Average loss at step 20000: 3.501081
# Nearest to system: derogatory, alpaca, systems, interrupts, hasidism, juries, reports, established,
# Nearest to five: four, six, seven, zero, eight, nine, two, three,
# Nearest to there: it, they, which, pontiff, he, these, marmara, macedon,
# Nearest to world: strain, cynical, u, pickup, following, uterus, ambrosia, deadlock,
# Nearest to war: stadler, restyled, earlier, ccc, ligature, unusually, och, kauffman,
# Nearest to these: some, many, such, all, their, which, alertness, several,
# Nearest to on: in, at, upon, sta, under, from, burgundians, teodoro,
# Nearest to however: but, that, ddo, later, beckham, though, nuggets, sahib,
# Nearest to about: brahmin, sosa, amato, cdb, am, pedal, lansing, tag,
# Nearest to often: sometimes, usually, also, commonly, generally, still, easier, kwh,
# Nearest to d: architecture, skunk, arthur, email, broca, ed, indignant, insiders,
# Nearest to called: substantive, milanese, backers, schisms, considered, orbiter, stamp, seleucus,
# Nearest to during: in, at, from, superheroes, underdeveloped, counsel, until, refutable,
# Nearest to their: its, his, the, these, deprived, them, sassanian, her,
# Nearest to so: psychoacoustics, mulder, drifted, tiger, meltzer, solano, newington, much,
# Nearest to see: dependable, purdue, drawback, trim, communes, inhibitor, chicagoland, dino,
# Average loss at step 22000: 3.501889
# Average loss at step 24000: 3.542882
# Average loss at step 26000: 3.562013
# Average loss at step 28000: 3.543219
# Average loss at step 30000: 3.507378
# Nearest to system: systems, derogatory, hasidism, juries, alpaca, surveyor, responsibility, altar,
# Nearest to five: seven, eight, six, four, three, nine, zero, two,
# Nearest to there: they, it, we, marmara, pontiff, these, he, usually,
# Nearest to world: strain, u, naka, uterus, deregulation, cynical, retention, kegan,
# Nearest to war: stadler, earlier, restyled, wastewater, charlemagne, ligature, developing, och,
# Nearest to these: some, many, several, all, such, which, various, there,
# Nearest to on: in, under, into, upon, at, sta, from, between,
# Nearest to however: but, that, while, though, later, banna, scapegoat, enchanted,
# Nearest to about: am, brahmin, pedal, amato, tag, cdb, appoints, foot,
# Nearest to often: sometimes, usually, commonly, also, generally, still, widely, who,
# Nearest to d: ed, broca, insiders, shamanism, skunk, perturbations, architecture, email,
# Nearest to called: substantive, milanese, referred, considered, schizophrenia, tz, seleucus, stamp,
# Nearest to during: in, after, from, until, at, dolmen, when, before,
# Nearest to their: its, his, the, her, southernmost, them, deprived, these,
# Nearest to so: mulder, tiger, aesthetically, wight, newington, went, solano, stratocaster,
# Nearest to see: drawback, dependable, zapu, purdue, communes, bernoulli, locative, akan,
# Average loss at step 32000: 3.478857
# Average loss at step 34000: 3.486549
# Average loss at step 36000: 3.499529
# Average loss at step 38000: 3.384414
# Average loss at step 40000: 3.458162
# Nearest to system: systems, derogatory, hasidism, network, juries, weyl, responsibility, alpaca,
# Nearest to five: four, six, seven, three, eight, nine, zero, one,
# Nearest to there: they, it, he, we, generally, usually, apprentices, not,
# Nearest to world: retention, strain, u, cynical, uterus, naka, country, auxerre,
# Nearest to war: stadler, och, ligature, restyled, ule, developing, logging, ccc,
# Nearest to these: many, some, several, their, such, which, different, various,
# Nearest to on: upon, under, through, into, in, from, burgundians, merseyside,
# Nearest to however: but, although, though, that, while, scapegoat, they, since,
# Nearest to about: am, cdb, pedal, brahmin, bow, amato, harappan, appoints,
# Nearest to often: usually, sometimes, commonly, generally, widely, still, frequently, also,
# Nearest to d: ed, b, architecture, broca, michael, isu, h, insiders,
# Nearest to called: used, considered, referred, seleucus, known, substantive, milanese, symonds,
# Nearest to during: in, after, until, before, from, first, dolmen, when,
# Nearest to their: its, his, her, the, your, these, some, our,
# Nearest to so: ointment, mulder, mankind, too, solano, auction, burials, hanse,
# Nearest to see: list, locative, pyrrhus, appeasement, capitol, include, seti, abel,
# Average loss at step 42000: 3.354911
# Average loss at step 44000: 3.471976
# Average loss at step 46000: 3.409993
# Average loss at step 48000: 3.402733
# Average loss at step 50000: 3.470923
# Nearest to system: systems, derogatory, weyl, juries, hasidism, responsibility, montage, virus,
# Nearest to five: four, six, seven, zero, eight, three, nine, two,
# Nearest to there: they, it, he, we, however, still, enclave, she,
# Nearest to world: country, naka, cruise, descriptor, phrygian, decade, occultation, impending,
# Nearest to war: stadler, switzer, restyled, earlier, accession, wastewater, och, ligature,
# Nearest to these: many, some, several, which, such, all, different, those,
# Nearest to on: in, upon, at, under, merseyside, about, into, hallucinatory,
# Nearest to however: but, although, that, while, though, there, saw, since,
# Nearest to about: cdb, brahmin, am, bow, on, harappan, pedal, usefully,
# Nearest to often: usually, sometimes, commonly, generally, also, still, frequently, now,
# Nearest to d: b, broca, architecture, isu, columbia, ed, odrade, neopagan,
# Nearest to called: used, referred, known, carboxylate, schizophrenia, named, considered, substantive,
# Nearest to during: in, when, after, under, until, for, at, through,
# Nearest to their: its, his, her, the, your, some, our, these,
# Nearest to so: ointment, too, before, mulder, thus, mankind, wight, solano,
# Nearest to see: include, can, capitol, vom, pyrrhus, becker, appeasement, locative,
# Average loss at step 52000: 3.405328
# Average loss at step 54000: 3.270021
# Average loss at step 56000: 3.398163
# Average loss at step 58000: 3.374661
# Average loss at step 60000: 3.412283
# Nearest to system: systems, derogatory, altar, endure, virus, process, dualism, autumn,
# Nearest to five: seven, six, four, eight, nine, three, zero, two,
# Nearest to there: they, it, he, still, we, she, bravely, generally,
# Nearest to world: country, europe, airstream, impending, cold, cruise, pickup, occultation,
# Nearest to war: stadler, switzer, accession, wastewater, wes, earlier, charlemagne, developing,
# Nearest to these: many, several, some, such, those, various, adverb, which,
# Nearest to on: upon, in, through, at, around, between, from, under,
# Nearest to however: but, although, that, though, while, since, still, absorbs,
# Nearest to about: cdb, brahmin, am, bow, interchangeability, staircase, olmec, cumings,
# Nearest to often: sometimes, usually, generally, commonly, also, still, frequently, widely,
# Nearest to d: b, broca, j, isu, michael, neopagan, tojo, o,
# Nearest to called: used, referred, known, considered, carboxylate, schizophrenia, symonds, seleucus,
# Nearest to during: in, after, until, when, at, since, following, under,
# Nearest to their: its, his, her, your, the, our, my, these,
# Nearest to so: too, before, thus, mulder, solano, wight, mankind, bju,
# Nearest to see: include, list, pyrrhus, refers, but, references, can, seti,
# Average loss at step 62000: 3.410740
# Average loss at step 64000: 3.379714
# Average loss at step 66000: 3.405097
# Average loss at step 68000: 3.298546
# Average loss at step 70000: 3.255002
# Nearest to system: systems, derogatory, dualism, responsibility, alpaca, autumn, oxfordshire, skipping,
# Nearest to five: four, seven, six, eight, three, nine, zero, two,
# Nearest to there: they, it, still, he, now, generally, often, she,
# Nearest to world: u, afghanistan, country, europe, cold, airstream, reagan, occultation,
# Nearest to war: stadler, wastewater, charlemagne, och, accession, wes, wars, reno,
# Nearest to these: many, some, several, those, such, they, both, various,
# Nearest to on: upon, in, through, zn, sta, intrigues, under, architectural,
# Nearest to however: but, although, though, while, that, following, especially, shutdown,
# Nearest to about: cumings, cdb, brahmin, amato, appoints, pay, umno, tag,
# Nearest to often: sometimes, usually, generally, commonly, still, frequently, now, also,
# Nearest to d: b, broca, ed, robert, unclassified, michael, montane, yukio,
# Nearest to called: used, referred, considered, known, schizophrenia, named, seleucus, gammu,
# Nearest to during: after, until, in, since, when, throughout, following, through,
# Nearest to their: its, his, her, the, your, our, some, sassanian,
# Nearest to so: too, thus, before, stratocaster, mankind, fp, ointment, wight,
# Nearest to see: list, references, include, enfants, pyrrhus, englewood, but, enthusiastic,
# Average loss at step 72000: 3.381217
# Average loss at step 74000: 3.260260
# Average loss at step 76000: 3.293351
# Average loss at step 78000: 3.338683
# Average loss at step 80000: 3.273265
# Nearest to system: systems, derogatory, process, endure, requirements, dependents, ethnographic, autumn,
# Nearest to five: seven, eight, six, four, nine, three, two, zero,
# Nearest to there: they, it, we, she, he, still, often, now,
# Nearest to world: cve, uefa, u, afghanistan, itunes, reagan, cold, heliogabalus,
# Nearest to war: billboards, occam, och, wars, stadler, battle, developing, switzer,
# Nearest to these: some, many, those, several, various, both, were, they,
# Nearest to on: upon, in, during, under, at, between, around, through,
# Nearest to however: but, although, though, that, while, since, there, following,
# Nearest to about: cdb, brahmin, cumings, wigner, amato, bow, appoints, harappan,
# Nearest to often: sometimes, usually, generally, commonly, frequently, still, now, widely,
# Nearest to d: b, michael, borer, broca, epithelial, applause, scuola, h,
# Nearest to called: considered, referred, known, used, carboxylate, seleucus, named, corporatist,
# Nearest to during: after, in, since, until, under, when, throughout, before,
# Nearest to their: its, his, her, our, your, both, my, these,
# Nearest to so: too, before, wight, nsson, thus, stratocaster, ointment, microbes,
# Nearest to see: references, list, include, pyrrhus, nightingale, crematoria, enfants, cycorp,
# Average loss at step 82000: 3.401056
# Average loss at step 84000: 3.348885
# Average loss at step 86000: 3.336303
# Average loss at step 88000: 3.109882
# Average loss at step 90000: 3.377670
# Nearest to system: systems, derogatory, process, endure, autumn, altar, alpaca, responsibility,
# Nearest to five: four, seven, six, eight, three, nine, two, zero,
# Nearest to there: they, it, still, he, we, now, usually, sometimes,
# Nearest to world: u, descriptor, cassady, departmental, galilee, afghanistan, cve, occultation,
# Nearest to war: battle, billboards, wars, distinction, developing, och, occam, accession,
# Nearest to these: some, many, those, several, various, such, certain, different,
# Nearest to on: upon, through, from, under, around, sta, at, during,
# Nearest to however: although, but, while, though, that, since, during, saw,
# Nearest to about: cdb, appoints, amato, brahmin, pay, bow, pedal, that,
# Nearest to often: sometimes, usually, commonly, generally, now, frequently, still, also,
# Nearest to d: b, c, h, dimensional, k, r, broca, goblin,
# Nearest to called: named, used, referred, known, carboxylate, considered, seleucus, schizophrenia,
# Nearest to during: after, since, when, until, before, from, throughout, although,
# Nearest to their: its, his, her, our, your, the, whose, some,
# Nearest to so: too, thus, before, dev, nsson, wight, ointment, monstrous,
# Nearest to see: include, can, list, bravely, includes, references, encamped, cycorp,
# Average loss at step 92000: 3.342833
# Average loss at step 94000: 3.369185
# Average loss at step 96000: 3.376166
# Average loss at step 98000: 3.360724
# Average loss at step 100000: 3.328063
# Nearest to system: systems, derogatory, requirements, process, alpaca, dependents, islamism, endure,
# Nearest to five: six, seven, four, eight, three, nine, zero, two,
# Nearest to there: they, it, he, still, we, sometimes, she, usually,
# Nearest to world: descriptor, u, occultation, cassady, galilee, cve, protestantism, mlp,
# Nearest to war: billboards, battle, hine, och, stadler, soe, wars, vietnam,
# Nearest to these: many, several, some, those, various, they, such, both,
# Nearest to on: upon, in, through, during, under, jem, deduces, around,
# Nearest to however: but, although, though, that, while, and, when, since,
# Nearest to about: cdb, charted, appoints, that, organically, wigner, umno, cumings,
# Nearest to often: sometimes, usually, commonly, generally, frequently, now, still, typically,
# Nearest to d: b, c, h, robert, dimensional, cdot, broca, odrade,
# Nearest to called: referred, named, known, used, corporatist, see, rococo, flory,
# Nearest to during: after, before, until, in, since, throughout, although, when,
# Nearest to their: its, his, her, your, our, the, whose, some,
# Nearest to so: too, thus, before, nsson, wight, dev, huis, nikos,
# Nearest to see: include, references, includes, can, list, bravely, refers, encamped,
# Paris - France + Rome = ['providing', 'mandolins', 'crumbs', 'arbuckle', 'depth'],

# %%
#num_points = 400
num_points = 50000

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
# Semantic-Syntactic Word Relationship test
#“Paris - France + Italy = ???”, “bigger - big + small = ???”

#print(final_embeddings[0])
#print(data[0])
#print(reverse_dictionary[5239])
#print(dictionary["paris"])
#print(count[5239])
#print(count[dictionary["france"]][1])

paris_emb=final_embeddings[count[dictionary["paris"]][1]]
france_emb=final_embeddings[count[dictionary["france"]][1]]
italy_emd=final_embeddings[count[dictionary["italy"]][1]]

#print(paris_emb-france_emb+italy_emd)
print(valid_dataset[2])
print(count[dictionary["paris"]][1])
# Out:
# Tensor("strided_slice:0", shape=(), dtype=int32)
# 1699

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# A method to build batch for training CBOW model
def generate_batch_cbow(data, batch_size, num_skips, skip_window):
    """
    Batch generator for CBOW (Continuous Bag of Words).
	batch should be a shape of (batch_size, num_skips)
	Parameters
	----------
	data: list of index of words
	batch_size: number of words in each mini-batch
	num_skips: number of surrounding words on both direction (2: one word ahead and one word following)
	skip_window: number of words at both ends of a sentence to skip (1: skip the first and last word of a sentence)
	"""
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)  # used for collecting data[data_index] in the sliding window
    # collect the first window of words
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # move the sliding window
    for i in range(batch_size):
        mask = [1] * span
        mask[skip_window] = 0
        batch[i, :] = list(np.compress(mask, buffer))  # all surrounding words. VD: swap the arguments
        labels[i, 0] = buffer[skip_window]  # the word at the center
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %%
# Step 4: Build and train a CBOW model.
data_index = 0

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():
    # Input data.

    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)


    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))


        embed = tf.zeros([batch_size, embedding_size])
        for j in range(num_skips):
            embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, j])

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(weights=nce_weights,
                       biases=nce_biases,
                       labels=train_labels,
                       inputs=embed,
                       num_sampled=num_sampled,
                       num_classes=vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.global_variables_initializer()
# Out:
# Initialized
# Average loss at step  0 :  309.738952637
# Nearest to of: provide, ore, baryonic, disillusionment, appointing, aiki, edmund, restraint,
# Nearest to been: verified, autodesk, database, hmso, asterisk, tempting, motive, interquartile,
# Nearest to had: undecided, blackboard, kummer, georgy, separating, hunters, hort, ambassador,
# Nearest to many: ole, cond, mechanism, bollywood, persia, governorates, successive, yangon,
# Nearest to a: astrologically, orbs, modulator, balance, derogatory, amassing, outbreaks, vied,
# Nearest to some: igneous, sensed, barriers, suit, lebowski, tubular, dodgers, sliding,
# Nearest to often: cuneiform, ghost, firestorm, codenamed, encroachment, lisboa, latvian, hum,
# Nearest to was: marjoram, vendetta, sleek, sacrum, tapered, garnering, dissociatives, philipp,
# Nearest to so: ruth, canmore, harness, caring, discreetly, cameo, dungeon, dix,
# Nearest to these: cotten, assimilated, plausibly, madame, appian, manufacturers, pogroms, interactive,
# Nearest to be: dem, arboretum, usurp, centronics, claudia, jimmu, conti, collectivization,
# Nearest to other: serge, rerio, crosley, uncountable, foix, prerogatives, interrelated, student,
# Nearest to he: frankel, kristen, hydrated, colbert, htm, pizza, everquest, opera,
# Nearest to while: phenotype, octagon, vesalius, mondegreen, zh, precinct, telekinesis, sappho,
# Nearest to people: urals, denial, inch, competition, horch, bocks, karami, blasting,
# Nearest to use: apart, abm, microclimates, mccartney, sensibility, destabilizing, hypoglycemic, thymus,
# Average loss at step  2000 :  69998.4082968
# Average loss at step  4000 :  49019.6083589
# Average loss at step  6000 :  26733.2901992
# Average loss at step  8000 :  20463.5840471
# Average loss at step  10000 :  17657.3032235
# Nearest to of: flight, same, demand, capital, comic, anglican, press, gothic,
# Nearest to been: become, received, survived, some, done, historians, further, i,
# Nearest to had: has, have, having, wrote, took, became, never, do,
# Nearest to many: someone, surviving, letters, ena, albuquerque, somerset, vermont, tomorrow,
# Nearest to a: itself, launched, classified, narrower, far, legend, symmetry, energy,
# Nearest to some: government, many, occasionally, produced, research, work, date, every,
# Nearest to often: sometimes, actually, usually, always, still, widely, frequently, considered,
# Nearest to was: is, are, became, wrote, while, took, were, by,
# Nearest to so: probably, occurred, originally, park, jews, successful, occur, electricity,
# Nearest to these: ideas, works, stories, citizens, frontier, usage, bin, groups,
# Nearest to be: take, never, similar, usually, archimedes, was, we, do,
# Nearest to other: south, political, western, observances, east, southern, ancient, third,
# Nearest to he: it, who, she, they, there, still, generally, usually,
# Nearest to while: is, when, if, upon, although, became, caught, after,
# Nearest to people: deg, localities, influential, melissa, clearance, unmarried, never, hone,
# Nearest to use: form, lack, loss, thousands, number, existence, rest, concept,
# Average loss at step  12000 :  12160.1134741
# Average loss at step  14000 :  13000.3104342
# Average loss at step  16000 :  15674.0505024
# Average loss at step  18000 :  10436.4622933
# Average loss at step  20000 :  9342.22599844
# Nearest to of: lowest, largest, primary, lower, mbox, marcuse, large, original,
# Nearest to been: become, be, were, often, being, never, remained, was,
# Nearest to had: has, have, having, since, never, already, alone, were,
# Nearest to many: several, some, various, areas, languages, sources, products, living,
# Nearest to a: the, advanced, weeks, incantation, accounting, months, dangerous, elements,
# Nearest to some: many, things, sources, towns, operations, each, quality, lading,
# Nearest to often: sometimes, now, actually, widely, frequently, commonly, traditionally, certainly,
# Nearest to was: became, is, exists, contains, remained, gives, were, becomes,
# Nearest to so: not, you, generally, jews, show, therefore, as, less,
# Nearest to these: they, many, there, units, both, keynesianism, which, chips,
# Nearest to be: become, been, is, being, were, longer, often, refer,
# Nearest to other: various, political, older, muslim, physical, support, ways, problems,
# Nearest to he: it, she, we, initially, probably, actually, cain, once,
# Nearest to while: covers, turning, reed, icing, windows, symphony, clay, defects,
# Nearest to people: individuals, those, angels, we, someone, women, scholars, thought,
# Nearest to use: badminton, formidable, antibiotics, polystyrene, laserdisc, maple, acquires, amorphous,
# Average loss at step  22000 :  8149.60184094
# Average loss at step  24000 :  8119.2491488
# Average loss at step  26000 :  8252.73396497
# Average loss at step  28000 :  7498.77877478
# Average loss at step  30000 :  5293.19198688
# Nearest to of: intellectual, same, surrounding, reserve, enters, definitive, reduces, remaining,
# Nearest to been: become, were, be, was, became, often, being, remained,
# Nearest to had: has, have, having, previously, never, originally, were, through,
# Nearest to many: several, numerous, languages, some, both, ideas, recent, modern,
# Nearest to a: exceptions, droppings, scale, weeks, transistors, decaying, hy, classification,
# Nearest to some: many, several, these, all, other, both, most, various,
# Nearest to often: usually, sometimes, now, commonly, generally, clearly, frequently, widely,
# Nearest to was: became, been, were, is, be, becomes, contains, does,
# Nearest to so: not, you, better, how, anything, exist, what, holes,
# Nearest to these: some, various, many, both, other, such, all, several,
# Nearest to be: been, being, become, refer, were, was, provide, move,
# Nearest to other: many, different, modern, several, others, various, times, some,
# Nearest to he: she, it, russell, ruth, finally, who, they, eventually,
# Nearest to while: wrote, before, concerning, involves, however, argues, lies, holds,
# Nearest to people: players, members, individuals, words, them, cases, jews, changes,
# Nearest to use: origin, rise, practice, importance, changes, terms, introduction, jews,
# Average loss at step  32000 :  6969.63356421
# Average loss at step  34000 :  6310.82286249
# Average loss at step  36000 :  61842.0827911
# Average loss at step  38000 :  123705.470628
# Average loss at step  40000 :  45448.0291912
# Nearest to of: universit, studi, sip, opposing, previous, tight, coyote, cimmerian,
# Nearest to been: become, fallen, remained, led, it, universe, language, always,
# Nearest to had: has, having, have, yet, did, makes, became, were,
# Nearest to many: some, several, other, different, numerous, these, various, those,
# Nearest to a: very, relatively, next, days, no, months, population, harbour,
# Nearest to some: many, several, other, all, each, different, any, most,
# Nearest to often: now, typically, still, currently, frequently, sometimes, clearly, we,
# Nearest to was: offers, remains, dolly, toe, cow, damaging, smoot, melancholic,
# Nearest to so: beyond, more, things, clearly, purer, not, reprisals, ye,
# Nearest to these: various, ldl, abbott, celts, patterns, rates, mi, cpus,
# Nearest to be: have, produce, refer, take, get, play, cause, vary,
# Nearest to other: different, various, these, historical, religious, older, others, times,
# Nearest to he: she, who, eventually, it, originally, finally, they, ruth,
# Nearest to while: although, however, saw, despite, when, include, via, during,
# Nearest to people: persons, patterns, leaders, advent, researchers, materials, symptoms, scope,
# Nearest to use: call, support, way, cause, decision, location, work, increase,
# Average loss at step  42000 :  23058.3462681
# Average loss at step  44000 :  59985.5692708
# Average loss at step  46000 :  23663.7411115
# Average loss at step  48000 :  15889.9399584
# Average loss at step  50000 :  21810.2669977
# Nearest to of: natural, inductive, whereby, baroque, dominican, scientific, solar, legislative,
# Nearest to been: become, already, was, previously, recently, gained, received, remained,
# Nearest to had: has, having, did, previously, never, wanted, reached, was,
# Nearest to many: various, protestant, language, materials, molino, barrister, fluids, hidden,
# Nearest to a: relatively, months, decades, any, days, very, enough, minutes,
# Nearest to some: other, several, certain, these, different, such, both, many,
# Nearest to often: sometimes, usually, generally, frequently, commonly, actually, now, widely,
# Nearest to was: were, is, took, remained, does, studied, had, becomes,
# Nearest to so: too, reaching, beyond, how, thus, larger, lower, more,
# Nearest to these: different, various, both, such, many, several, all, some,
# Nearest to be: being, refer, create, take, lead, offer, increase, pass,
# Nearest to other: different, some, such, several, various, these, many, others,
# Nearest to he: she, originally, who, finally, previously, eventually, earnhardt, initially,
# Nearest to while: although, though, wrote, were, where, are, despite, believe,
# Nearest to people: those, men, works, individuals, others, fans, christians, doctor,
# Nearest to use: cause, introduction, appointment, return, premiere, codeine, start, run,
# Average loss at step  52000 :  15688.0082419
# Average loss at step  54000 :  14305.8499722
# Average loss at step  56000 :  12756.5494886
# Average loss at step  58000 :  17935.7771281
# Average loss at step  60000 :  11812.9567298
# Nearest to of: preparatory, to, within, minestrone, transfers, uruguayan, compression, crests,
# Nearest to been: become, already, previously, begun, gained, come, evolved, was,
# Nearest to had: has, got, having, previously, already, wrote, declared, have,
# Nearest to many: some, various, certain, several, few, these, living, such,
# Nearest to a: very, any, relatively, too, tours, dressed, hatched, enough,
# Nearest to some: many, various, both, certain, different, these, all, several,
# Nearest to often: usually, generally, commonly, sometimes, frequently, currently, widely, still,
# Nearest to was: got, had, is, becomes, became, wrote, been, newly,
# Nearest to so: too, how, thus, beyond, back, easier, more, less,
# Nearest to these: various, such, both, different, certain, some, many, including,
# Nearest to be: lead, reach, refer, create, happen, produce, cause, being,
# Nearest to other: different, various, all, such, these, including, many, both,
# Nearest to he: she, eventually, originally, initially, finally, subsequently, previously, officially,
# Nearest to while: where, hoddle, painted, previews, laboratory, claimed, dass, scandinavian,
# Nearest to people: individuals, men, others, words, those, christians, critics, persons,
# Nearest to use: think, collapse, decline, occurrence, exiles, contents, purchase, classics,
# Average loss at step  62000 :  2016819.56591
# Average loss at step  64000 :  1379133.3687
# Average loss at step  66000 :  697595.011133
# Average loss at step  68000 :  560531.766564
# Average loss at step  70000 :  1023705.37339
# Nearest to of: signifies, torpedoes, nicene, thickness, fem, theorized, repressed, heian,
# Nearest to been: become, fallen, never, ever, previously, finland, always, changed,
# Nearest to had: has, have, having, never, previously, actually, became, was,
# Nearest to many: some, several, these, various, any, synclavier, all, most,
# Nearest to a: any, its, fgc, pounds, boyars, escorts, untrue, proceed,
# Nearest to some: these, control, poems, every, macedonia, sumatra, implementation, many,
# Nearest to often: widely, generally, available, sometimes, largely, significantly, valid, replaced,
# Nearest to was: became, were, involves, remains, gives, icon, fujiwara, incentive,
# Nearest to so: larger, thus, yet, models, error, therefore, check, indeed,
# Nearest to these: those, programs, examples, functional, elements, scripts, fatwas, soldiers,
# Nearest to be: cause, have, refer, find, allow, lead, bring, provide,
# Nearest to other: various, these, verbal, some, political, novels, faster, smaller,
# Nearest to he: she, therefore, hurt, freyr, subsequently, already, ahern, stalin,
# Nearest to while: infrastructure, transfers, tunnelling, maintains, mentions, crossed, analyse, nagano,
# Nearest to people: countries, parts, formulas, casualty, several, transportation, eastern, kinds,
# Nearest to use: offer, soldiers, location, survivor, transfer, purposes, beverly, wwi,
# Average loss at step  72000 :  478634.360762
# Average loss at step  74000 :  361699.403441
# Average loss at step  76000 :  439019.279158
# Average loss at step  78000 :  333528.448955
# Average loss at step  80000 :  307281.906729
# Nearest to of: royale, naacp, hungary, magyars, historiography, photos, flickr, study,
# Nearest to been: become, ever, grown, traditionally, successfully, being, was, survived,
# Nearest to had: has, have, having, never, yet, previously, was, been,
# Nearest to many: several, various, parts, some, such, applications, these, countries,
# Nearest to a: theory, any, large, doses, binary, liquid, chromosome, another,
# Nearest to some: numerous, inclinations, loathing, planting, oswald, entrepot, perugia, sodom,
# Nearest to often: usually, frequently, sometimes, generally, traditionally, always, rarely, simply,
# Nearest to was: were, is, been, has, being, newly, involves, contains,
# Nearest to so: frequently, generally, too, widely, often, extremely, increasingly, highly,
# Nearest to these: several, some, clint, grape, dormant, retreating, combatant, snobol,
# Nearest to be: make, happen, win, lead, cause, allow, remain, take,
# Nearest to other: faster, these, religious, individual, some, larger, slavic, better,
# Nearest to he: she, they, there, harrison, never, eventually, who, gallienus,
# Nearest to while: produces, like, nf, lies, arrived, facing, explaining, hobbyist,
# Nearest to people: students, americans, monster, cars, close, riddler, objects, writers,
# Nearest to use: cause, lack, implementation, rest, value, end, consist, fall,
# Average loss at step  82000 :  354326.352859
# Average loss at step  84000 :  274028.638352
# Average loss at step  86000 :  347808.940295
# Average loss at step  88000 :  268014.296324
# Average loss at step  90000 :  202031.863148
# Nearest to of: einer, entire, second, sociopathic, baird, esb, postpositions, doris,
# Nearest to been: become, was, ever, yet, being, previously, be, already,
# Nearest to had: has, was, have, were, been, traditionally, already, never,
# Nearest to many: several, various, some, these, few, those, such, other,
# Nearest to a: another, relatively, league, too, escarpment, very, something, enough,
# Nearest to some: these, many, both, several, all, other, certain, various,
# Nearest to often: frequently, usually, typically, widely, therefore, generally, rarely, still,
# Nearest to was: has, been, had, became, were, is, newly, being,
# Nearest to so: too, sometimes, know, later, officially, remain, thus, rapidly,
# Nearest to these: some, such, both, different, those, certain, other, various,
# Nearest to be: refer, have, become, lead, make, been, take, cause,
# Nearest to other: various, several, gib, different, slavic, nationalist, individual, functional,
# Nearest to he: she, eventually, never, who, amin, gradually, they, soon,
# Nearest to while: krush, unlike, involving, furthermore, concerning, before, sari, sounded,
# Nearest to people: laxness, flops, olympics, ong, hosting, meredith, std, quantifier,
# Nearest to use: form, consist, collections, request, start, existence, follow, jews,
# Average loss at step  92000 :  188492.035898
# Average loss at step  94000 :  1570194.77915
# Average loss at step  96000 :  280476.405871
# Average loss at step  98000 :  354256.634809
# Average loss at step  100000 :  159732.36794
# Nearest to of: antipopes, hier, tatiana, weaning, axial, ganz, reintroducing, mondale,
# Nearest to been: recently, had, previously, already, become, begun, amassed, yet,
# Nearest to had: has, been, have, previously, was, never, having, were,
# Nearest to many: several, various, some, parts, values, ethnic, types, countries,
# Nearest to a: hospitals, modernity, interpretations, charters, overlaps, sizes, cannes, allowable,
# Nearest to some: these, any, rimbaud, different, integration, each, proponents, jesus,
# Nearest to often: sometimes, widely, now, frequently, commonly, usually, rarely, also,
# Nearest to was: is, had, been, were, became, has, seems, be,
# Nearest to so: too, easier, slower, conn, healing, acoustic, envelope, polymyositis,
# Nearest to these: different, coding, davison, komm, seventeen, niue, affiliated, cryptographic,
# Nearest to be: cause, refer, lead, become, take, make, get, seem,
# Nearest to other: others, various, these, different, younger, fewer, hindus, historical,
# Nearest to he: levy, biafra, who, cubana, instead, carter, blew, apparently,
# Nearest to while: although, marines, condemning, conversely, lacks, throughout, heralds, wherein,
# Nearest to people: communities, individuals, metals, commentators, disposition, gospels, nous, swans,
# Nearest to use: form, introduction, adventures, descendents, remainder, stand, rank, queen,

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):

        batch_inputs, batch_labels = generate_batch_cbow(data, batch_size=batch_size, num_skips=num_skips,
                                                skip_window=skip_window)
        feed_dict = {train_dataset: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  314.850219727
# Nearest to of: bucket, waid, burroughs, hor, oa, cabot, readable, myr,
# Nearest to been: weekends, malan, excellent, clovis, abernathy, mangaverse, bicoid, url,
# Nearest to had: edmunds, galactus, mundane, cbm, bastille, pitt, gonzo, celebrity,
# Nearest to many: mckenzie, bendix, dormant, bavaria, fsln, detectors, hinges, ashore,
# Nearest to a: polytechnic, champ, buns, bornholm, novo, pikemen, amoxicillin, rigidly,
# Nearest to some: beavis, denizens, yakovlev, hatta, plagioclase, citations, disco, brut,
# Nearest to often: vows, physiologic, amiable, somber, fleece, mellor, freshmen, greeneville,
# Nearest to was: italo, topaz, accountant, targets, ordinated, list, radiant, beltane,
# Nearest to so: breisgau, gesenius, celebrities, sampled, condoned, moser, lensing, thursdays,
# Nearest to these: sparingly, continuing, thz, mongoloid, pdf, mistake, kk, entrances,
# Nearest to be: eastwards, moynihan, haddo, bin, lieutenant, fiefs, firewall, deserving,
# Nearest to other: payable, lipstick, demarco, photius, tutoring, experiments, amundsen, breath,
# Nearest to he: measures, legends, interacted, openvms, parchment, bulldog, slavonic, boldness,
# Nearest to while: venturi, bauhaus, randy, limelight, pompeii, feathered, leicestershire, tangible,
# Nearest to people: notate, noyce, collectivist, arouse, sammon, tooth, castillo, euphoric,
# Nearest to use: westview, immanence, brownish, sihanouk, ganymede, justin, viterbo, sensations,
# Average loss at step  2000 :  104.633150913
# Average loss at step  4000 :  47.2636378698
# Average loss at step  6000 :  29.3508209167
# Average loss at step  8000 :  20.3141967825
# Average loss at step  10000 :  14.9313004129
# Nearest to of: in, expansionism, and, kipsigis, lilongwe, mint, for, wedgwood,
# Nearest to been: actually, compounds, was, also, assaulted, meteor, balance, kuru,
# Nearest to had: has, pitt, have, boogie, was, binding, played, eccles,
# Nearest to many: some, stamina, give, mondays, him, heroic, dormant, novels,
# Nearest to a: the, cyrus, mainframe, christ, education, itosu, worldwide, discoveries,
# Nearest to some: many, utilized, connecting, christians, peress, plagioclase, disco, exertion,
# Nearest to often: vows, amiable, ev, when, xor, measurement, secrete, riot,
# Nearest to was: is, has, operates, were, keynesianism, been, had, seek,
# Nearest to so: breisgau, timeline, gesenius, celebrities, tolerated, significance, report, ketones,
# Nearest to these: pdf, yukon, minutes, sparingly, edirne, nora, region, administrations,
# Nearest to be: ci, have, galatians, mitchell, frankish, lettuce, walkway, was,
# Nearest to other: property, photius, leland, ultimately, simon, outstanding, leger, tannenberg,
# Nearest to he: it, she, who, osh, eros, kuwait, they, applied,
# Nearest to while: randy, limelight, panavia, panel, memorable, venturi, applications, smyrna,
# Nearest to people: notate, arouse, itosu, nativity, arbitrary, deep, institution, situations,
# Nearest to use: virus, justin, jdl, frequent, sihanouk, smalltalk, jng, producers,
# Average loss at step  12000 :  19.6521875454
# Average loss at step  14000 :  11.389869505
# Average loss at step  16000 :  9.41147400463
# Average loss at step  18000 :  7.08619807303
# Average loss at step  20000 :  6.35770521426
# Nearest to of: for, and, in, within, during, scoping, lilongwe, elderly,
# Nearest to been: was, be, heracles, actually, also, were, meteor, usually,
# Nearest to had: has, have, was, pitt, colbert, binding, boogie, played,
# Nearest to many: some, dormant, cellar, several, all, heroic, overhead, sins,
# Nearest to a: the, lubrication, another, apc, lensing, this, alteration, qu,
# Nearest to some: many, several, victories, peress, bala, het, connecting, exertion,
# Nearest to often: vows, measurement, topology, causal, seconds, amiable, ev, ebay,
# Nearest to was: is, has, were, had, been, be, became, seek,
# Nearest to so: gesenius, lensing, breisgau, significance, report, celebrities, tolerated, ketones,
# Nearest to these: wolsey, thz, other, llamas, their, yukon, laminar, shotguns,
# Nearest to be: have, was, were, is, been, galatians, ci, interviewing,
# Nearest to other: leger, photius, these, property, efficiencies, deathbed, chalcedon, heroic,
# Nearest to he: it, she, who, they, seng, bcpl, ross, later,
# Nearest to while: limelight, during, borland, panavia, randy, venturi, offers, memorable,
# Nearest to people: arouse, notate, ligament, itosu, plunkett, unheard, castillo, situations,
# Nearest to use: oppressed, sihanouk, jdl, viterbo, westview, finley, invoke, virus,
# Average loss at step  22000 :  6.00098170471
# Average loss at step  24000 :  5.69039140046
# Average loss at step  26000 :  5.43466481376
# Average loss at step  28000 :  5.22533640039
# Average loss at step  30000 :  5.06723875713
# Nearest to of: in, and, wallabies, lilongwe, slovenia, wedgwood, for, during,
# Nearest to been: be, was, were, pyre, orbiting, actually, heracles, become,
# Nearest to had: has, have, was, were, is, colbert, pitt, eventually,
# Nearest to many: some, several, all, dormant, autoimmune, these, other, cellar,
# Nearest to a: lubrication, pngimage, shimbun, lep, kzin, ecuadorian, mythology, mjt,
# Nearest to some: many, several, jdl, all, these, lithograph, factum, equinox,
# Nearest to often: generally, measurement, vows, usually, also, seconds, topology, not,
# Nearest to was: is, has, were, had, became, extinct, orca, arteries,
# Nearest to so: report, lensing, arteries, significance, gesenius, ketones, breisgau, bran,
# Nearest to these: some, shotguns, other, their, many, laminar, wolsey, romero,
# Nearest to be: have, been, were, are, was, galatians, is, become,
# Nearest to other: leger, these, photius, efficiencies, many, property, morihei, chalcedon,
# Nearest to he: she, it, they, who, later, seng, there, potters,
# Nearest to while: during, however, when, applications, offers, memorable, minestrone, mig,
# Nearest to people: arouse, notate, ligament, plunkett, itosu, castillo, movement, arbitrary,
# Nearest to use: viterbo, jdl, oppressed, invoke, sense, westview, sihanouk, moqed,
# Average loss at step  32000 :  1296.91178449
# Average loss at step  34000 :  1440.78524891
# Average loss at step  36000 :  476.313806082
# Average loss at step  38000 :  336.632731054
# Average loss at step  40000 :  227.791936993
# Nearest to of: like, in, including, lilongwe, neale, vilayet, analog, eds,
# Nearest to been: become, had, be, was, coens, were, come, never,
# Nearest to had: has, have, was, were, having, been, became, led,
# Nearest to many: some, several, these, all, other, various, such, most,
# Nearest to a: lubrication, very, first, situations, eight, or, any, alteration,
# Nearest to some: many, these, all, several, any, this, which, others,
# Nearest to often: generally, still, sometimes, widely, frequently, commonly, she, largely,
# Nearest to was: is, were, are, has, had, became, though, being,
# Nearest to so: too, thus, then, today, considered, highly, not, sometimes,
# Nearest to these: property, journal, brow, different, communism, both, programming, signer,
# Nearest to be: have, become, being, been, according, find, refer, form,
# Nearest to other: these, different, others, many, property, people, contributions, amazons,
# Nearest to he: it, they, she, there, then, who, we, but,
# Nearest to while: although, does, were, if, but, consider, is, gm,
# Nearest to people: sanjaks, episcopal, obey, albania, intel, criteria, art, togo,
# Nearest to use: work, end, course, right, prince, title, school, level,
# Average loss at step  42000 :  231.386023909
# Average loss at step  44000 :  134.390484451
# Average loss at step  46000 :  96.6377463827
# Average loss at step  48000 :  83.1784135451
# Average loss at step  50000 :  129.689848133
# Nearest to of: like, among, with, real, western, dalai, same, following,
# Nearest to been: become, was, had, be, term, never, were, by,
# Nearest to had: has, have, were, been, was, having, never, contains,
# Nearest to many: some, several, these, various, such, other, all, most,
# Nearest to a: relatively, very, any, another, lubrication, first, months, mataram,
# Nearest to some: many, these, several, all, various, any, such, both,
# Nearest to often: generally, sometimes, usually, commonly, still, frequently, always, now,
# Nearest to was: is, were, has, being, became, been, had, himself,
# Nearest to so: not, too, more, thus, sometimes, less, you, achieved,
# Nearest to these: such, some, many, both, including, all, various, several,
# Nearest to be: have, been, refer, become, was, being, never, according,
# Nearest to other: various, different, many, others, these, such, several, smaller,
# Nearest to he: she, it, they, who, later, there, we, then,
# Nearest to while: although, but, however, where, though, when, are, until,
# Nearest to people: others, words, things, those, writers, times, acres, countries,
# Nearest to use: support, six, sense, form, movement, range, site, edge,
# Average loss at step  52000 :  88.6703034101
# Average loss at step  54000 :  128.406345905
# Average loss at step  56000 :  74.3675165253
# Average loss at step  58000 :  54.5602584472
# Average loss at step  60000 :  56.0755792685
# Nearest to of: storylines, ascii, bigfoot, alpine, balinese, bmw, x, jpg,
# Nearest to been: become, had, was, be, were, already, come, ever,
# Nearest to had: have, has, having, was, ever, were, under, already,
# Nearest to many: several, some, various, such, these, all, other, those,
# Nearest to a: very, relatively, another, plunges, every, their, derision, energetically,
# Nearest to some: many, several, these, various, all, other, such, those,
# Nearest to often: usually, now, frequently, generally, agp, ballads, turnip, harbour,
# Nearest to was: is, has, had, began, became, were, remained, but,
# Nearest to so: thus, too, not, report, time, before, now, bahia,
# Nearest to these: such, many, some, including, other, various, different, all,
# Nearest to be: refer, being, been, become, produce, have, remain, gain,
# Nearest to other: various, these, many, different, such, several, smaller, others,
# Nearest to he: she, it, who, they, originally, there, already, never,
# Nearest to while: when, although, but, where, involved, and, like, during,
# Nearest to people: jews, communities, especially, acres, enumerates, aphrodite, bakersfield, cma,
# Nearest to use: support, sense, work, practice, presence, form, sound, study,
# Average loss at step  62000 :  44.7232515721
# Average loss at step  64000 :  52.8991194472
# Average loss at step  66000 :  128.648518326
# Average loss at step  68000 :  55.4281006212
# Average loss at step  70000 :  65.1336083212
# Nearest to of: basque, cauchy, comment, constantine, capitalist, hexagon, sq, without,
# Nearest to been: become, were, be, was, come, being, had, begun,
# Nearest to had: has, have, having, were, was, since, already, ever,
# Nearest to many: these, various, some, several, studies, amazons, judo, bioinformatics,
# Nearest to a: relatively, any, mitrokhin, another, sondheim, philosophie, lubrication, spores,
# Nearest to some: many, several, various, all, other, these, certain, different,
# Nearest to often: usually, sometimes, commonly, generally, now, still, typically, frequently,
# Nearest to was: is, were, became, being, had, been, remains, originally,
# Nearest to so: thus, too, sometimes, not, how, before, hugh, starks,
# Nearest to these: six, list, greg, cupid, constantinople, dickens, constantine, bioinformatics,
# Nearest to be: refer, become, been, being, provide, remain, ci, take,
# Nearest to other: various, many, different, some, these, others, including, smaller,
# Nearest to he: she, it, they, who, originally, there, eventually, newly,
# Nearest to while: although, though, like, when, however, including, but, offers,
# Nearest to people: those, men, women, humans, buildings, others, players, writers,
# Nearest to use: support, sense, work, presence, form, history, rise, range,
# Average loss at step  72000 :  41.5638012877
# Average loss at step  74000 :  45.6616438375
# Average loss at step  76000 :  25.1621398945
# Average loss at step  78000 :  41.8362749588
# Average loss at step  80000 :  33.2091492002
# Nearest to of: crimean, vandal, and, clin, coalition, frieza, auburn, specialise,
# Nearest to been: become, be, were, was, had, by, being, recently,
# Nearest to had: has, have, having, were, since, been, already, previously,
# Nearest to many: several, some, various, all, these, other, those, such,
# Nearest to a: derision, pessimism, alteration, beta, encrypt, overheat, steeply, arkansas,
# Nearest to some: many, several, various, these, any, all, certain, other,
# Nearest to often: usually, sometimes, commonly, now, cvd, generally, typically, always,
# Nearest to was: orioles, curling, comment, fermanagh, dylan, lemur, bioinformatics, eurocents,
# Nearest to so: thus, then, too, sometimes, hugh, now, if, leaves,
# Nearest to these: such, many, both, some, various, several, different, all,
# Nearest to be: become, been, refer, remain, being, is, have, was,
# Nearest to other: various, smaller, different, many, others, these, some, religious,
# Nearest to he: she, it, who, they, originally, was, tardive, never,
# Nearest to while: when, although, but, though, or, like, where, after,
# Nearest to people: women, players, men, words, buildings, humans, children, those,
# Nearest to use: sense, support, work, presence, range, play, return, help,
# Average loss at step  82000 :  31.2241267003
# Average loss at step  84000 :  27.9124384637
# Average loss at step  86000 :  25.8291252594
# Average loss at step  88000 :  20.8290489852
# Average loss at step  90000 :  19.5764768517
# Nearest to of: climbing, togo, currents, ashkenazi, sedgwick, creativity, archimedean, week,
# Nearest to been: be, become, were, was, had, already, being, recently,
# Nearest to had: has, have, was, having, were, since, been, already,
# Nearest to many: several, some, various, all, other, these, those, such,
# Nearest to a: relatively, another, any, every, philosophie, defectors, dramatic, shimbun,
# Nearest to some: many, various, several, all, these, any, other, certain,
# Nearest to often: usually, sometimes, generally, commonly, now, also, frequently, typically,
# Nearest to was: is, had, were, been, became, has, being, himself,
# Nearest to so: too, now, breed, thus, suggests, ballads, during, county,
# Nearest to these: various, such, several, those, many, other, some, all,
# Nearest to be: been, refer, become, remain, have, was, keep, being,
# Nearest to other: various, different, many, including, these, several, smaller, religious,
# Nearest to he: she, they, it, who, eventually, never, there, actually,
# Nearest to while: although, when, but, though, however, including, or, like,
# Nearest to people: women, men, humans, players, jews, buildings, those, others,
# Nearest to use: support, sense, work, allow, help, return, study, rest,
# Average loss at step  92000 :  221.217197469
# Average loss at step  94000 :  181.290503843
# Average loss at step  96000 :  202.601397849
# Average loss at step  98000 :  75.009951623
# Average loss at step  100000 :  777.465156008
# Nearest to of: perform, increases, aerobic, k, dual, j, direct, flamenco,
# Nearest to been: become, not, to, never, usually, also, which, begun,
# Nearest to had: has, was, is, were, would, since, seems, did,
# Nearest to many: several, various, other, such, some, these, few, certain,
# Nearest to a: zealand, york, any, ado, mal, written, actuated, packed,
# Nearest to some: million, drake, logic, cycle, k, furigana, indigenous, data,
# Nearest to often: usually, generally, also, sometimes, traditionally, typically, which, always,
# Nearest to was: is, has, however, when, had, may, be, were,
# Nearest to so: things, thus, report, increases, buffer, perform, jamil, lytton,
# Nearest to these: many, such, several, different, various, all, other, those,
# Nearest to be: according, was, refer, cause, occur, have, were, make,
# Nearest to other: various, many, smaller, different, individual, bizkit, indebtedness, these,
# Nearest to he: she, it, already, there, they, who, originally, now,
# Nearest to while: when, though, however, during, but, consider, in, first,
# Nearest to people: men, won, areas, king, fifo, import, fast, k,
# Nearest to use: carry, have, support, consider, decision, head, approach, application,

# %%
# Step 6: Visualize the embeddings.


def plot_with_labels(low_dim_embs, labels, filename='tsne_jupyter.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)


try:
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels)

except ImportError:
    print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")
